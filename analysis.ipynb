# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('C:/Users/Sean/Desktop/Analysis_data/xhpi_output.csv')

# %%
df_filtered = data[data['xhpi'] == 1]

xhpi_1_rows = data[data['xhpi'] == 1]
print(data.shape)
print(xhpi_1_rows.shape)
data.head(3)
# Out:
# (3160109, 22)
# (393871, 22)
#   pdb_name  resolution  mean_b_factor pi_chain_name  pi_residue_number  \
# 0     3db7         1.4        10.6325             A                 38
# 1     3db7         1.4        10.7575             A                 38
# 2     3db7         1.4        11.7675             A                 38
#
#   pi_residue_name                        pi_center_array  \
# 0             PHE  [ 8.46316667 50.06066667 16.42166667]
# 1             PHE  [ 8.46316667 50.06066667 16.42166667]
# 2             PHE  [ 8.46316667 50.06066667 16.42166667]
#
#                         pi_normal_vector  pi_b_factor X_chain_name  ...  \
# 0  [-0.16568781 -0.52649926  0.83387414]       12.225            A  ...
# 1  [-0.16568781 -0.52649926  0.83387414]       12.225            A  ...
# 2  [-0.16568781 -0.52649926  0.83387414]       12.225            A  ...
#
#    X_element_name X_atom_name                   X_pos X_b_factor H_atom_name  \
# ...

# %%
distance = 'X_to_pi_center_distance'

plt.figure(figsize=(6, 4))
sns.histplot(data[distance], bins=1000, kde=False)

plt.title(f'xhpi = 1  "{distance}" ')
plt.xlabel(distance)
plt.ylabel('count')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
distance = 'XH_picenterAngle'

plt.figure(figsize=(6, 4))
sns.histplot(data[distance], bins=1000, kde=False)

plt.title(f'xhpi = 1  "{distance}" ')
plt.xlabel(distance)
plt.ylabel('count')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
distance = 'XPCN_angle'

plt.figure(figsize=(6, 4))
sns.histplot(df_filtered[distance], bins=1000, kde=False)

plt.title(f'xhpi = 1  "{distance}" ')
plt.xlabel(distance)
plt.ylabel('count')
plt.grid(True)
plt.tight_layout()
plt.show()
